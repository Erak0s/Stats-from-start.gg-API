# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Florian/Desktop/roa2_rank_repartition.csv", sep=";", )

# %%
import matplotlib.pyplot as plt

plt.plot(data["Rank"],data["Elo"])#,data["Rank"])
plt.xticks(list(range(200,1,-20))+[1])
plt.gca().invert_xaxis()
plt.yticks([min(data["Elo"]),1550,1600,1650,1700,1750,1800,1850,1900,1950,max(data["Elo"])])
plt.show()
